# %%
import networkx as nx, matplotlib.pyplot as plt
import numpy as np, pandas as pd
import math, seaborn as sns
from scipy import stats
from sklearn import cluster as clstr
from networkx import edge_betweenness_centrality
from networkx.algorithms import community
import itertools
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
df1 = pd.read_csv('C:/Users/saich/OneDrive/Desktop/SNA/project/marvel_characters.csv')
df2 = pd.read_csv('C:/Users/saich/OneDrive/Desktop/SNA/project/marvel_titles.csv')

# %%
GT = nx.Graph()
new_G = nx.Graph()
#GT.add_nodes_from(df['character'].tolist(),bipartite=1,node_color='w',alpha=0.4,node_shape='d')

for index, row in df2.iterrows():
  GT.add_node(row['title'] + '*', bipartite=0, media_type=row['type'], release_year=row['release_year'], release_month=row['release_month'], release_day=row['release_day'], rating=row['rating'], length=row['length'], starts=row['stars'], genres=row['genres'])

# %%
for index, row in df1.iterrows():
  if row['title'] == 'What If...?':
    char_name = row['character'] + '-AR'
  else:
    char_name = row['character']
  GT.add_node(char_name, bipartite=1, alias=row['character_alias'], actor=row['actor'])

for index, row in df1.iterrows():
  if row['title'] == 'What If...?':
    char_name = row['character'] + '-AR'
  else:
    char_name = row['character']
  GT.add_edge(row['title'] + '*', char_name)

# %%
#GT.add_nodes_from(df2['title'].tolist(),bipartite=0,  node_color='red', alpha=0.4, node_shape='s')
#for i in range(len(df.index)):
 #   GT.add_edge(df2.at[i,'title'],df1.at[i,'character'])

# %%
character_nodes = {n for n, d in GT.nodes(data=True) if d['bipartite'] == 1}
title_nodes = set(GT) - character_nodes

# %%
len(character_nodes) # number of characters
# Out:
# 794

# %%
len(title_nodes) # titles count
# Out:
# 60

# %%
len(GT.edges)
# Out:
# 1142

# %%
#pos = nx.spring_layout(GT)
#nx.draw(GT)
pos = nx.spring_layout(GT)
nx.draw(GT)#,pos,with_labels=True,font_color='red')

# %%
list(GT.neighbors('Tony Stark'))
#List of Marvel movies Tony Stark acted
# Out:
# ['Iron Man*',
#  'Iron Man 2*',
#  'The Avengers*',
#  'Iron Man 3*',
#  'Avengers: Age of Ultron*',
#  'Captain America: Civil War*',
#  'Spider-Man: Homecoming*',
#  'Avengers: Infinity War*',
#  'Avengers: Endgame*']

# %%
list(GT.neighbors('Avengers: Age of Ultron*'))
#Main characters in the Avengers: Age of Ultron
# Out:
# ['Tony Stark',
#  'Thor',
#  'Bruce Banner',
#  'Steve Rogers',
#  'Natasha Romanoff',
#  'Clint Barton',
#  'Ultron',
#  'Nick Fury',
#  'James Rhodes',
#  'Pietro Maximoff',
#  'Wanda Maximoff',
#  'Jarvis',
#  'Maria Hill',
#  'Sam Wilson',
#  'Heimdall',
#  'Laura Barton',
#  'Erik Selvig',
#  'Dr. Helen Cho',
#  'Strucker',
#  'Ulysses Klaue',
#  'Friday']

# %%
# To find the Similarities between the nodes
def Jaccard_Cosine_Smlrty(G,l):
    num = list(set([n for n in G.neighbors(l[0])]) & set([m for m in G.neighbors(l[1])]))
    print('Common between the',l[0],'and', l[1],'are', num)
    denom_j = list(set([n for n in G.neighbors(l[0])] + [m for m in G.neighbors(l[1])]))
    print('Jaccard Similarity is ', len(num)/len(denom_j))
    denom_c = math.sqrt(len([n for n in G.neighbors(l[0])])*len([n for n in G.neighbors(l[1])]))
    print('Cosine Similarity is', len(num)/denom_c)

# %%
l = ['Tony Stark','Steve Rogers']
Jaccard_Cosine_Smlrty(GT,l)
# Out:
# Common between the Tony Stark and Steve Rogers are ['The Avengers*', 'Avengers: Infinity War*', 'Avengers: Endgame*', 'Captain America: Civil War*', 'Avengers: Age of Ultron*']
# Jaccard Similarity is  0.45454545454545453
# Cosine Similarity is 0.629940788348712

# %%
l2= ['Avengers: Age of Ultron*', 'Avengers: Endgame*']
Jaccard_Cosine_Smlrty(GT,l2)
# Out:
# Common between the Avengers: Age of Ultron* and Avengers: Endgame* are ['Friday', 'Tony Stark', 'Clint Barton', 'Jarvis', 'Maria Hill', 'Steve Rogers', 'Nick Fury', 'Natasha Romanoff', 'Thor', 'Laura Barton', 'Sam Wilson', 'Wanda Maximoff', 'James Rhodes', 'Bruce Banner']
# Jaccard Similarity is  0.2028985507246377
# Cosine Similarity is 0.3879917968315853

# %% [markdown]
# ### Isolated Components

# %%
# isolated components
i= nx.number_connected_components(GT)
i
# Out:
# 6

# %%
[GT.subgraph(c).copy() for c in nx.connected_components(GT)]
# Out:
# [<networkx.classes.graph.Graph at 0x1fb188fe640>,
#  <networkx.classes.graph.Graph at 0x1fb188fe040>,
#  <networkx.classes.graph.Graph at 0x1fb188fe6a0>,
#  <networkx.classes.graph.Graph at 0x1fb188fe550>,
#  <networkx.classes.graph.Graph at 0x1fb188fe2e0>,
#  <networkx.classes.graph.Graph at 0x1fb188fed90>]

# %%
for c in nx.connected_components(GT):
    print(c)
# Out:
# {'Doctor Strange*', 'Kaecilius', "Benjamin 'Dex' Poindexter", 'Diego', 'Ruben', 'Thor', 'Holden Holliway', 'Detective Andrew Henry', 'Wanda Maximoff', 'Emil Blonsky', 'Hai-Qing Yang', 'Comanche', 'Taserface-AR', 'The Avengers*', 'Porcupine', 'Betty Ross', 'Sheikh Abdullah', 'White Power Dave', "N'Jobu", 'Paul Edmonds', 'Daniel Drumm', 'Colonel Victor Ramon', 'Madame Gao', 'Louise Thompson', 'Morgan Stark', 'Akihiko', 'Darryl', 'Groot', 'Maya Hansen', 'Secretary Ross-AR', 'Marvel One-Shot: Item 47*', 'Carol', 'Herman', 'Nebula-AR', 'Luis', 'Anansi', 'Night Waitress', 'Vernon Masters', 'Aida', 'Ultron', 'Captain Tom Ridenhour', 'Skaar', 'David Schultz', 'Enrique', 'Auntie Ruby', 'Jemma Simmons', 'Tiny', 'MJ', 'Carl Lucas', 'Pepper Potts', 'William Ginter Riva', 'Mrs. Davis', 'Yelena Boleva', 'Ying Nan', 'Jessica Jones', 'Sal Blaskowski', 'Topaz', 'Elektra Natchios', 'Friday', 'Dr. Bill Foster', 'Griffin Sinclair', 'Harley Keener', 'Derek', 'Maria Hill-AR', 'AJ', 'Jason Ionello', 'FSB Commander', 'Okoye-AR', 'Avengers: Age of Ultron*', "Marvel One-Shot: A Funny Thing Happened on the Way to Thor's Hammer*", 'Kamran', 'Jessica Jones*', 'Turk Barrett', 'Detective Rafael Scarfe', 'Cornell Stokes', 'Anton Ivanov', 'Aldrich Killian', 'Benjamin Donovan', 'She-Hulk: Attorney at Law*', 'Queen Ramonada-AR', 'Gorgon', 'Hank', 'Lance Hunter', 'Agent Ford', 'Ayesha', 'Murakami', "Peter's To-Do List*", 'Sammy', 'Albert Rackham', 'Holden Radcliffe', 'The Ancient One-AR', 'Skeevy Guy', 'The Collector-AR', 'Colonel Chester Phillips', 'Tony stark-AR', 'Jon Jon', 'Peggy Carter', 'Dreykov', 'Dr. Otto Octavius', 'Judge Price', 'Sharon Carter-AR', 'Ravonna Renslayer', 'Phil Jones', 'Proxima Midnight', 'Klev', 'Lei Kung', 'Paxton', 'Nico', 'Gregory Sallinger', 'Battlestar', 'Wong', 'Wendy', 'Grant Ward', 'Iron Man*', 'The Ancient One', 'Dr. Christine Palmer', 'Mr. Berkowitz', 'Mobius', 'Sinara', 'Peter Parker', 'Yondu', 'Tony Stark', 'Detective Rivera', 'He Who Remains', 'Shaun', 'Agent Sitwell', 'Happy Hogan', 'Runa', 'Colleen Wing', 'Curtis Hoyle', 'Dr. Noah Burstein', 'Frank Castle', 'Gigi', 'Herman Schultz', 'Thor: The Dark World*', 'Betty Ross-AR', 'Aamir', 'Dr. Erskine-AR', 'Spider-Man: Homecoming*', 'Olivia Walker', 'Adrian Toomes', 'God of Thunder', 'Carlo Eastman', 'Black Panther*', 'Alexandra Reid', 'The Defenders*', 'Rosalie Carbone', 'Jack Murdock', "Maximillian 'Max' Tatum", 'Iron Man 2*', 'Victoria', 'Skurge', 'Billy Russo', 'Dale', 'Calvin Zabo', 'Ulysses Klaue-AR', 'Agent Davis', "W'Kabi", 'Iwua', 'Peter Quill-AR', 'Trish Walker', 'Yinsen', 'Natasha Romanoff', 'Aaron Davis', 'Gao Lei', 'Carson Wolf', 'Dwayne Blaskowski', 'Special Agent Sonya Falsworth', 'Red Dagger', 'Mitchell Ellison', 'Bronaja', 'Dr. Christine Palmer-AR', 'Rufus', 'Casey', 'Sowande', 'Peter Lyonne', 'Corvus Glaive', 'Ruihua', 'Gordon', 'Cooper Barton', 'Dr. Christina Raynor', 'Mouse', 'Dottie Underwood', 'Kilgrave', 'Dave', 'Krista Dumont', 'E.D.I.T.H.', 'Marvel One-Shot: All Hail the King*', 'Peter Parker3', 'Thanos', 'Dr. Arnim Zola', 'Shuri-AR', 'Dorothy', 'Hugh Jones', 'Volstagg', 'Donald', 'Thanos-AR', 'Maximus', "O'Bengh-AR", 'Mr. Dell', 'Kitang', 'Jack Duquesne', 'Vision', 'DeeDee', 'Peter Quill', 'Bruno', 'Bobby Fish', 'Bruce Banner-AR', 'Dr. Hank Pym', 'Beverly', 'Frank', 'Talos', 'Pietro Maximoff', 'Ultron-AR', 'Baron Mordo', 'Sergei', 'Alonso Barber', 'Agents of S.H.I.E.L.D.*', 'Dana Stryker', 'Colonel Flynn-AR', 'Marilyn', 'Inhumans*', 'Reed Richards', 'Hank Pym-AR', 'Liz', 'Jim Morita', 'Sonny Burch', 'Wendy Ross-Hogarth', 'James Rhodes-AR', 'Gamora', 'Maggie', 'Dr. Evan Declan', 'JARVIS', 'Iron Fist*', 'Steve Rogers', 'Matt Murdock', 'Avengers: Endgame*', 'Monica Rambeau', 'Louise', 'Jane Foster', 'Brock Rumlow-AR', 'Robyn', 'Det. Oscar Clemons', 'Obadiah Stane', 'Alpha Dog', 'Georges Batroc', 'Lieutenant Perez', 'Razor Fist', 'Hope Van Dyne', 'Vido Arocho', 'Erik Killmonger', 'Carol Danvers', 'Young Xialing', 'Sif-AR', 'Christine Everhart', 'Jimmy Woo', ...
# {'Leslie Dean', 'Amy Minoru', 'Runaways*', 'Mike on a Bike', 'Dagger', 'Bronwyn', 'Frances', 'Topher', 'Dale Yorkes', 'Otis Johnson', 'Duane Porter', 'Peter Scarborough', 'Morgan le Fay', 'Nathan Bowen', 'Molly Hernandez', 'Cloak', 'Chase Stein', 'Evita Fusilier', 'Lia', 'Livvie', 'Karolina Dean', 'Robert Minoru', 'Destiny Gonzalez', 'Detective Flores', 'Choo Choo Broussard', 'Mikayla Bell', 'Catherine Wilder', 'Frank Dean', 'Jonah', 'Victor Stein', 'Gert Yorkes', 'Stacey Yorkes', 'Liam Walsh', 'Janet Stein', 'Tina Minoru', 'Eiffel', 'Adina Johnson', 'Mina Hess', 'Nico Minoru', 'Melissa Bowen', 'Cloak & Dagger*', 'Ivan Hess', "Detective Brigid O'Reilly", 'Aura', 'Susan Ellerh', 'Detective Connors', 'Graciela Aguirre', 'Darius', 'Officer Fuchs', 'Vaughn', 'Millennial Megan', 'Andre Deschaine', 'Tamar', "Anthony 'AWOL' Wall", 'Xavin', 'Geoffrey Wilder', 'Auntie Chantelle', 'Solomon', 'Alex Wilder'}
# {'Gabriella Rosetti', 'Jolene Spivey', 'Archbishop Terrazi', 'Aubree Richards', 'Bryce', 'Kthara', 'Lee', 'Father Joshua Crow', 'Finn', 'Esther', 'Helstrom*', 'Officer Derrick Jackson', 'Papa', 'Dr. Louise Hastings', 'Victoria Helstrom', 'Cameron Tate', 'Ana Helstrom', 'Alex Tilden', 'Keith Spivey', 'Ellis', 'Chris Yen', 'Daimon Helstrom'}
# {'Druig', 'Kro', 'Thena', 'Phastos', 'Eros', 'Dane Whitman', 'Ben', 'Makkari', 'Kingo', 'Sersi', 'Sprite', 'Ikaris', 'Jack', 'Eternals*', 'Arishem', 'Gilgamesh', 'Ajak', 'Karun'}
# {'Crawley', 'J.B.', 'Arthur Harrow', 'Bek', 'Wendy Spector', 'Donna', 'Taweret', 'Khonshu', 'Marc Spector', 'Billy', 'Selim', 'Yatzil', 'Layla El-Faouly', 'Anton Mogart', 'Bobbi', 'Moon Knight*'}
# {'Jack Russell', 'Azarel', 'Barasso', 'Verussa', 'Jovan', 'Liorn', 'Ulysses Bloodstone', 'Billy Swan', 'The Flaming Tuba', 'Elsa Bloodstone', 'Ted (The Man-Thing)', 'Werewolf by Night*'}

# %% [markdown]
# ### 6 Clusters are
# #### 1 - Werewolf by Night
# #### 2 - Moon Knight
# #### 3 - Eternals
# #### 4 - Helstrom
# #### 5 - Cloak & Dagger' & Runaways
# #### 6 - WHIH News Front, The Falcon and the Winter Soldier, Guardians of the Galaxy Vol. 2, Marvel One-Shot: The Consultant, Doctor Strange, Iron Man, Thor, The Avengers, Daredevil, The Incredible Hulk, Avengers: Endgame, Thor: Love and Thunder, Avengers: Age of Ultron, Iron Man 2, Marvel One-Shot: All Hail the King, Hawkeye, The Defenders, Marvel One-Shot: A Funny Thing Happened on the Way to Thor's Hammer, Doctor Strange in the Multiverse of Madness, Iron Fist, WandaVision, Peter's To-Do List, Captain America: The First Avenger, Guardians of the Galaxy, What If...?, Secret Invasion, Black Panther, Thor: Ragnarok, She-Hulk: Attorney at Law, Agents of S.H.I.E.L.D.: Slingshot, Captain America: Civil War, The Punisher, Luke Cage, Spider-Man: Far from Home, Captain Marvel, Iron Man 3, Inhumans, Loki, Jessica Jones, Agent Carter, Agents of S.H.I.E.L.D., Marvel One-Shot: Item 47, Spider-Man: No Way Home, I Am Groot, Marvel One-Shot: Agent Carter, Ant-Man, Shang-Chi and the Legend of the Ten Rings, Thor: The Dark World, Captain America: The Winter Soldier, Ms. Marvel,cAnt-Man and the Wasp, Black Widow, Avengers: Infinity War, Spider-Man: Homecoming

# %%
nx.node_connected_component(GT,'Werewolf by Night*')
# Out:
# {'Azarel',
#  'Barasso',
#  'Billy Swan',
#  'Elsa Bloodstone',
#  'Jack Russell',
#  'Jovan',
#  'Liorn',
#  'Ted (The Man-Thing)',
#  'The Flaming Tuba',
#  'Ulysses Bloodstone',
#  'Verussa',
#  'Werewolf by Night*'}

# %%
#df2.at[2,'title']
#GT.neighbors('Werewolf by Night*')
set([n for n in GT.neighbors('Werewolf by Night*')])
# Out:
# {'Azarel',
#  'Barasso',
#  'Billy Swan',
#  'Elsa Bloodstone',
#  'Jack Russell',
#  'Jovan',
#  'Liorn',
#  'Ted (The Man-Thing)',
#  'The Flaming Tuba',
#  'Ulysses Bloodstone',
#  'Verussa'}

# %%
#Isolated Network of Werewolf team 
G_Werewolf = nx.Graph()
hrs = list(set([n for n in GT.neighbors('Werewolf by Night*')]))
for j in range(len(df1.index)):
    if (df1.at[j,'character'] in hrs ):
        G_Werewolf.add_edge("Werewolf by Night*",df1.at[j,'character'])
        #print(1)
nx.draw(G_Werewolf,with_labels=True, font_color='black')

# %%
nx.node_connected_component(GT,"Eternals*")
# Out:
# {'Ajak',
#  'Arishem',
#  'Ben',
#  'Dane Whitman',
#  'Druig',
#  'Eros',
#  'Eternals*',
#  'Gilgamesh',
#  'Ikaris',
#  'Jack',
#  'Karun',
#  'Kingo',
#  'Kro',
#  'Makkari',
#  'Phastos',
#  'Sersi',
#  'Sprite',
#  'Thena'}

# %%
#Isolated Network of Eternals team 
G_Eternals = nx.Graph()
# for i in range(len(df2.index)):
#     if (df2.at[i,'title'] == 'Eternals*'):G_Eternals.add_edge(df2.at[i,'title'],df2.at[i,'character'])
hrs = list(set([n for n in GT.neighbors('Eternals*')]))
for j in range(len(df1.index)):
    if (df1.at[j,'character'] in hrs ):
        G_Eternals.add_edge("Eternals*",df1.at[j,'character'])
       
nx.draw(G_Eternals,with_labels=True, font_color='black')

# %%
nx.node_connected_component(GT,"Moon Knight*")
# Out:
# {'Anton Mogart',
#  'Arthur Harrow',
#  'Bek',
#  'Billy',
#  'Bobbi',
#  'Crawley',
#  'Donna',
#  'J.B.',
#  'Khonshu',
#  'Layla El-Faouly',
#  'Marc Spector',
#  'Moon Knight*',
#  'Selim',
#  'Taweret',
#  'Wendy Spector',
#  'Yatzil'}

# %%
G_Moon_Knight = nx.Graph()
# for i in range(len(df2.index)):
#     if (df2.at[i,'title'] == 'Moon Knight*'):G_Moon_Knight.add_edge(df2.at[i,'title'],df2.at[i,'character'])
hrs = list(set([n for n in GT.neighbors('Moon Knight*')]))
for j in range(len(df1.index)):
    if (df1.at[j,'character'] in hrs ):
        G_Moon_Knight.add_edge("Moon Knight*",df1.at[j,'character'])
nx.draw(G_Moon_Knight,with_labels=True, font_color='black')

# %%
nx.node_connected_component(GT,"Helstrom*")
# Out:
# {'Alex Tilden',
#  'Ana Helstrom',
#  'Archbishop Terrazi',
#  'Aubree Richards',
#  'Bryce',
#  'Cameron Tate',
#  'Chris Yen',
#  'Daimon Helstrom',
#  'Dr. Louise Hastings',
#  'Ellis',
#  'Esther',
#  'Father Joshua Crow',
#  'Finn',
#  'Gabriella Rosetti',
#  'Helstrom*',
#  'Jolene Spivey',
#  'Keith Spivey',
#  'Kthara',
#  'Lee',
#  'Officer Derrick Jackson',
#  'Papa',
#  'Victoria Helstrom'}

# %%
G_Helstrom = nx.Graph()
# for i in range(len(df.index)):
#     if (df.at[i,'title'] == 'Helstrom*'):G_Helstrom.add_edge(df.at[i,'title'],df.at[i,'character'])
hrs = list(set([n for n in GT.neighbors('Helstrom*')]))
for j in range(len(df1.index)):
    if (df1.at[j,'character'] in hrs ):
        G_Helstrom.add_edge("Helstrom*",df1.at[j,'character'])
nx.draw(G_Helstrom,with_labels=True, font_color='black')

# %%
nx.node_connected_component(GT,'Cloak & Dagger*')
# 'Runaways' or 'Cloak & Dagger' titles are in same cluster
# Out:
# {'Adina Johnson',
#  'Alex Wilder',
#  'Amy Minoru',
#  'Andre Deschaine',
#  "Anthony 'AWOL' Wall",
#  'Auntie Chantelle',
#  'Aura',
#  'Bronwyn',
#  'Catherine Wilder',
#  'Chase Stein',
#  'Choo Choo Broussard',
#  'Cloak',
#  'Cloak & Dagger*',
#  'Dagger',
#  'Dale Yorkes',
#  'Darius',
#  'Destiny Gonzalez',
#  "Detective Brigid O'Reilly",
#  'Detective Connors',
#  'Detective Flores',
#  'Duane Porter',
#  'Eiffel',
#  'Evita Fusilier',
#  'Frances',
#  'Frank Dean',
#  'Geoffrey Wilder',
#  'Gert Yorkes',
#  'Graciela Aguirre',
#  'Ivan Hess',
#  'Janet Stein',
#  'Jonah',
#  'Karolina Dean',
#  'Leslie Dean',
#  'Lia',
#  'Liam Walsh',
#  'Livvie',
#  'Melissa Bowen',
#  'Mikayla Bell',
#  'Mike on a Bike',
#  'Millennial Megan',
#  'Mina Hess',
#  'Molly Hernandez',
#  'Morgan le Fay',
#  'Nathan Bowen',
#  'Nico Minoru',
#  'Officer Fuchs',
#  'Otis Johnson',
#  'Peter Scarborough',
#  'Robert Minoru',
#  'Runaways*',
#  'Solomon',
#  'Stacey Yorkes',
#  'Susan Ellerh',
#  'Tamar',
#  'Tina Minoru',
#  'Topher',
#  'Vaughn',
#  'Victor Stein',
#  'Xavin'}

# %%
G_CDR = nx.Graph()
# for i in range(len(df.index)):
#     if (df.at[i,'title'] == 'Cloak & Dagger*' or df.at[i,'title'] == 'Runaways*'):
hrs1 = list(set([n for n in GT.neighbors('Cloak & Dagger*')]))
hrs2 = list(set([n for n in GT.neighbors('Runaways*')]))
for j in range(len(df1.index)):
    if (df1.at[j,'character'] in hrs1):
        G_CDR.add_edge("Cloak & Dagger*",df1.at[j,'character'])
    if  (df1.at[j,'character'] in hrs2):
        G_CDR.add_edge("Runaways*",df1.at[j,'character'])
nx.draw(G_CDR,with_labels=True, font_color='black')

# %% [markdown]
# ### Parameters

# %%
def deg_dst(G7): # degree distribution of titles and characters
    degrees = [G7.degree(n) for n in title_nodes]
    deg,freq = np.unique(degrees,return_counts=True)
    plt.plot(deg,freq,label = 'title degree distribution')
    plt.legend()
    plt.show()
    degrees1 = [G7.degree(n) for n in character_nodes]
    deg1,freq1 = np.unique(degrees1,return_counts=True)
    plt.plot(deg1,freq1,label = 'characters degree distribution')
    plt.legend()
    plt.show()
def avg_deg_cc(G): # average degree and clustering co-efficient
    avg_cc_G = nx.transitivity(G)
    avg_deg_G = G.degree()
    deg_sum_G =0
    for j in list(avg_deg_G):
        deg_sum_G += j[1]
    avg_deg_G =  deg_sum_G/len(G.nodes())
    return (avg_deg_G, avg_cc_G)

# %%
def deg_dst_Graph(G7):
    degrees = [G7.degree(n) for n in G7.nodes()]
    deg,freq = np.unique(degrees,return_counts=True)
    plt.plot(deg,freq,label = 'Total nodes degree distribution')
    plt.legend()
    plt.show()

# %%
avg_deg_, avg_clstrng_ = avg_deg_cc(GT) 
#print('Average degree of Network', avg_deg_,'clustering co-efficient', avg_clstrng_)

# %%
num = 0 
for c in nx.connected_components(GT):
    num += nx.average_shortest_path_length(GT.subgraph(c))*len(GT.subgraph(c))

# %%
GT_avg_path = num/len(GT.nodes())

# %%
print("MU Network \n ")
print("Average degree" ,avg_deg_ )
print("Average path",GT_avg_path)
print("Average clusteirng", avg_clstrng_)
print("MU netwok graph diameter is", max([max(j.values()) for (i,j) in nx.shortest_path_length(GT)]))
# Out:
# MU Network
#
# Average degree 2.6744730679156907
# Average path 5.8150060878361405
# Average clusteirng 0
# MU netwok graph diameter is 10

# %% [markdown]
# ### As there is no connection between the actors, so no formation of triangles which leads to "0" transitivity

# %%
deg_dst(GT)

# %%
deg_dst_Graph(GT)

# %%
#des = [GT.degree(n) for n in title_nodes]
titles_dict ={}
characters_dict={}
for n in title_nodes: 
    titles_dict.update({n:GT.degree(n)})
for n in character_nodes:
    characters_dict.update({n:GT.degree(n)})  
#list(des)

# %%
#Degrees of Titles and characters
print('Chracters degree',characters_dict)
print('\n titles degree',titles_dict)
# Out:
# Chracters degree {'Azarel': 1, 'Jolene Spivey': 1, "Benjamin 'Dex' Poindexter": 1, 'Kaecilius': 1, 'Diego': 1, 'Ruben': 1, 'Thor': 6, 'Holden Holliway': 1, 'Detective Andrew Henry': 1, 'Wanda Maximoff': 6, 'Emil Blonsky': 1, 'Comanche': 1, 'Hai-Qing Yang': 1, 'Taserface-AR': 1, 'Ted (The Man-Thing)': 1, 'Porcupine': 1, 'Betty Ross': 1, 'Billy': 1, 'Sheikh Abdullah': 1, 'White Power Dave': 1, "N'Jobu": 1, 'Paul Edmonds': 1, 'Daniel Drumm': 1, 'Madame Gao': 3, 'Louise Thompson': 1, 'Colonel Victor Ramon': 1, 'Morgan Stark': 1, 'Akihiko': 1, 'Darryl': 1, 'Groot': 4, 'Maya Hansen': 1, 'Secretary Ross-AR': 1, 'Carol': 1, 'Herman': 1, 'Layla El-Faouly': 1, 'Nebula-AR': 1, 'Luis': 2, 'Anansi': 1, 'Night Waitress': 1, 'Vernon Masters': 1, 'Aida': 1, 'Ultron': 2, 'Captain Tom Ridenhour': 1, 'Officer Fuchs': 1, 'Skaar': 1, 'Phastos': 1, 'David Schultz': 1, 'Enrique': 1, 'Auntie Ruby': 1, 'Jemma Simmons': 2, 'Geoffrey Wilder': 1, 'MJ': 3, 'Carl Lucas': 1, 'Xavin': 1, 'Pepper Potts': 7, 'Tiny': 1, 'William Ginter Riva': 2, 'Mrs. Davis': 1, 'Ying Nan': 1, 'Sal Blaskowski': 1, 'Jessica Jones': 2, 'Yelena Boleva': 1, 'Topaz': 1, 'Elektra Natchios': 2, 'Friday': 4, 'Leslie Dean': 1, 'Dr. Bill Foster': 1, 'Griffin Sinclair': 1, 'Harley Keener': 1, 'Maria Hill-AR': 1, 'Ben': 1, 'Derek': 1, 'AJ': 1, 'Jason Ionello': 1, 'Okoye-AR': 1, 'FSB Commander': 1, 'Kamran': 1, 'Otis Johnson': 1, 'Turk Barrett': 4, 'Detective Rafael Scarfe': 1, 'Cornell Stokes': 1, 'Aldrich Killian': 1, 'Anton Ivanov': 1, 'Benjamin Donovan': 2, 'Chase Stein': 1, 'Queen Ramonada-AR': 1, 'Gorgon': 1, 'Hank': 1, 'Agent Ford': 1, 'Lance Hunter': 1, 'Ayesha': 1, 'Murakami': 1, 'Sammy': 1, 'Father Joshua Crow': 1, 'Albert Rackham': 1, 'Holden Radcliffe': 1, 'Stacey Yorkes': 1, 'The Ancient One-AR': 1, 'Ajak': 1, 'The Collector-AR': 1, 'Skeevy Guy': 1, 'Colonel Chester Phillips': 1, 'Tony stark-AR': 1, 'Jon Jon': 1, 'Peggy Carter': 6, 'Dreykov': 1, 'Dr. Otto Octavius': 1, 'Shar
#  titles degree {'Doctor Strange*': 8, 'Guardians of the Galaxy*': 12, 'Iron Fist*': 22, 'Runaways*': 38, 'The Falcon and the Winter Soldier*': 31, 'Spider-Man: No Way Home*': 23, 'Ant-Man*': 14, 'WandaVision*': 19, 'Avengers: Endgame*': 62, 'Spider-Man: Far from Home*': 20, 'What If...?*': 68, 'Avengers: Age of Ultron*': 21, "Marvel One-Shot: A Funny Thing Happened on the Way to Thor's Hammer*": 1, 'Agents of S.H.I.E.L.D.: Slingshot*': 11, 'Jessica Jones*': 57, 'The Punisher*': 24, 'Marvel One-Shot: All Hail the King*': 6, 'Marvel One-Shot: Agent Carter*': 4, 'Iron Man 3*': 15, 'Thor: The Dark World*': 14, 'The Avengers*': 15, 'Thor: Ragnarok*': 16, 'Captain America: The First Avenger*': 11, 'Loki*': 8, 'She-Hulk: Attorney at Law*': 42, 'Spider-Man: Homecoming*': 11, 'Black Panther*': 13, 'The Defenders*': 21, "Peter's To-Do List*": 4, 'The Incredible Hulk*': 5, 'Eternals*': 17, 'Doctor Strange in the Multiverse of Madness*': 19, 'Secret Invasion*': 9, 'Helstrom*': 21, 'Ms. Marvel*': 16, 'Hawkeye*': 18, 'Iron Man 2*': 13, 'Werewolf by Night*': 11, 'WHIH News Front*': 5, 'Captain America: The Winter Soldier*': 14, 'Captain Marvel*': 11, 'Daredevil*': 22, 'Marvel One-Shot: Item 47*': 4, 'Thor: Love and Thunder*': 22, 'Cloak & Dagger*': 21, 'Agents of S.H.I.E.L.D.*': 47, 'Luke Cage*': 42, 'Thor*': 15, 'Avengers: Infinity War*': 41, 'Black Widow*': 8, 'Guardians of the Galaxy Vol. 2*': 13, 'Shang-Chi and the Legend of the Ten Rings*': 21, 'Marvel One-Shot: The Consultant*': 3, 'Agent Carter*': 26, 'Captain America: Civil War*': 21, 'Iron Man*': 13, 'Inhumans*': 23, 'Ant-Man and the Wasp*': 12, 'I Am Groot*': 3, 'Moon Knight*': 15}

# %%
new_G_char = nx.bipartite.projected_graph(GT,character_nodes)
print(new_G_char)
# Out:
# Graph with 794 nodes and 14793 edges

# %%
nx.transitivity(new_G_char)
# Out:
# 0.7865580748804692

# %%
nx.draw(new_G_char)

# %%
avg_deg_bi, avg_clstrng_bi = avg_deg_cc(new_G_char) 
num = 0 
for c in nx.connected_components(new_G_char):
    num += nx.average_shortest_path_length(new_G_char.subgraph(c))*len(new_G_char.subgraph(c))
GT_avg_path_bi = num/len(new_G_char.nodes())

# %%
print("Bi-partite Network \n ")
print("Average degree" ,avg_deg_bi )
print("Average path",GT_avg_path_bi)
print("Average clusteirng", avg_clstrng_bi)
print("bi-partite graph diameter is", max([max(j.values()) for (i,j) in nx.shortest_path_length(new_G_char)]))#.subgraph(component)))
# Out:
# Bi-partite Network
#
# Average degree 37.26196473551637
# Average path 2.9716587201631284
# Average clusteirng 0.7865580748804692
# bi-partite graph diameter is 5

# %% [markdown]
# ### Random Simlated graph

# %%
GT_p = avg_deg_ /(len(GT.nodes())-1) # caliculating probability
GT_nodes=len(GT.nodes())
print('Random model probability value',GT_p, 'and length of nodes', GT_nodes)
# Out:
# Random model probability value 0.003135372881495534 and length of nodes 854

# %%
GT_sim_rndm = nx.gnp_random_graph(GT_nodes, GT_p)

# %%
# Simulated Random 
avg_deg_sim, avg_clstrng_sim =  avg_deg_cc(GT_sim_rndm)

# %% [markdown]
# #### Isoloated graphs in network

# %%
i= nx.number_connected_components(GT_sim_rndm)
i
# Out:
# 81

# %%
num = 0 
for c in nx.connected_components(GT_sim_rndm):
    num += nx.average_shortest_path_length(GT_sim_rndm.subgraph(c))*len(GT_sim_rndm.subgraph(c))
GT_sim_avg_path = num/len(GT_sim_rndm.nodes())

# %%
print("Random Simulated MU Network \n ")
print("Average degree" ,avg_deg_sim)
print("Average path", GT_sim_avg_path)
print("Average clusteirng", avg_clstrng_sim)
print("Random graph diameter is",max([max(j.values()) for (i,j) in nx.shortest_path_length(GT_sim_rndm)]))
# Out:
# Random Simulated MU Network
#
# Average degree 2.529274004683841
# Average path 6.167207582658724
# Average clusteirng 0.002151308712800287
# Random graph diameter is 17

# %%
val1= GT_sim_avg_path/GT_avg_path
print(' Average path of Random Model Graph is ',val1,'times the average path of Marvel Uuniverse')
#val2 =  avg_clstrng_sim/avg_clstrng_
#print('Clustering co-efficient of Random graph is',val2)#'times the Clustering co-efficient of Marvel Uuniverse')
# Out:
#  Average path of Random Model Graph is  1.0605676915041105 times the average path of Marvel Uuniverse

# %%
deg_dst_Graph(GT_sim_rndm)

# %% [markdown]
# ### Preferential Algorithm Method

# %% [markdown]
# #### Connecting 'Moon Knight', 'Eternals', 'Helstrom', 'Cloak & Dagger' & 'Runaways' and 'Werewolf by Night' clusters' actors (nodes) to the base(main) cluster based on the Preferential Algorithm Method
# #### Comparing the clustering co-efficient, average path and degree distribution of new network with the actual MU network

# %%
new_nodes=list()
new_nodes1 = list(GT.neighbors('Werewolf by Night*'))
for i in new_nodes1: new_nodes.append(i)
new_nodes2= list(GT.neighbors('Moon Knight*'))
for i in new_nodes2: new_nodes.append(i)
new_nodes3= list(GT.neighbors('Eternals*'))
for i in new_nodes3: new_nodes.append(i)
new_nodes4= list(GT.neighbors('Helstrom*'))
for i in new_nodes4: new_nodes.append(i)
new_nodes5 = list(GT.neighbors('Runaways*'))
for i in new_nodes5: new_nodes.append(i)
new_nodes6 = list(GT.neighbors('Cloak & Dagger*'))
for i in new_nodes6: new_nodes.append(i)
print(new_nodes) # Nodes (actors) adding to the base cluster
print(len(new_nodes))
# Out:
# ['Jack Russell', 'Elsa Bloodstone', 'Verussa', 'Jovan', 'Azarel', 'Liorn', 'Barasso', 'Billy Swan', 'Ted (The Man-Thing)', 'The Flaming Tuba', 'Ulysses Bloodstone', 'Marc Spector', 'Arthur Harrow', 'Layla El-Faouly', 'Khonshu', 'Bobbi', 'Billy', 'Taweret', 'Selim', 'Crawley', 'Donna', 'Yatzil', 'J.B.', 'Bek', 'Anton Mogart', 'Wendy Spector', 'Sersi', 'Ikaris', 'Thena', 'Ajak', 'Dane Whitman', 'Kingo', 'Sprite', 'Phastos', 'Makkari', 'Druig', 'Gilgamesh', 'Karun', 'Kro', 'Ben', 'Jack', 'Eros', 'Arishem', 'Daimon Helstrom', 'Ana Helstrom', 'Victoria Helstrom', 'Gabriella Rosetti', 'Dr. Louise Hastings', 'Chris Yen', 'Keith Spivey', 'Father Joshua Crow', 'Finn', 'Esther', 'Bryce', 'Officer Derrick Jackson', 'Ellis', 'Jolene Spivey', 'Alex Tilden', 'Archbishop Terrazi', 'Cameron Tate', 'Lee', 'Kthara', 'Papa', 'Aubree Richards', 'Alex Wilder', 'Nico Minoru', 'Karolina Dean', 'Gert Yorkes', 'Chase Stein', 'Molly Hernandez', 'Catherine Wilder', 'Geoffrey Wilder', 'Janet Stein', 'Victor Stein', 'Stacey Yorkes', 'Dale Yorkes', 'Robert Minoru', 'Leslie Dean', 'Tina Minoru', 'Frank Dean', 'Jonah', 'Xavin', 'Tamar', 'Vaughn', 'Darius', 'Frances', 'Aura', 'Morgan le Fay', "Anthony 'AWOL' Wall", 'Eiffel', 'Livvie', 'Detective Flores', 'Bronwyn', 'Destiny Gonzalez', 'Amy Minoru', 'Millennial Megan', 'Susan Ellerh', 'Topher', 'Graciela Aguirre', 'Mike on a Bike', 'Dagger', 'Cloak', 'Dagger', 'Cloak', 'Adina Johnson', "Detective Brigid O'Reilly", 'Melissa Bowen', 'Detective Connors', 'Evita Fusilier', 'Otis Johnson', 'Auntie Chantelle', 'Nathan Bowen', 'Lia', 'Mina Hess', 'Andre Deschaine', 'Officer Fuchs', 'Liam Walsh', 'Solomon', 'Peter Scarborough', 'Mikayla Bell', 'Duane Porter', 'Ivan Hess', 'Choo Choo Broussard']
# 123

# %%
# Removing 'Moon Knight','Eternals', 'Helstrom', 'Cloak & Dagger' & Runaways' and 'Werewolf by Night' clusters from the main graph
GT_p = GT.copy()
for i in new_nodes: 
    if i in GT_p.nodes(): GT_p.remove_node(i)
GT_p.remove_node('Moon Knight*')
GT_p.remove_node('Eternals*')
GT_p.remove_node('Helstrom*')
GT_p.remove_node('Cloak & Dagger*') 
GT_p.remove_node('Runaways*')
GT_p.remove_node('Werewolf by Night*')
print("Node count in actual MU network",len(GT.nodes()))
print("Removing the nodes including the small clusters titles",len(new_nodes))
print("Node count after removing nodes from the MU network",len(GT_p.nodes()))
# Out:
# Node count in actual MU network 854
# Removing the nodes including the small clusters titles 123
# Node count after removing nodes from the MU network 727

# %%
def PAM(G,avg_deg,new_nodes):
    node_count=len(G.nodes())
    G_PAM = nx.Graph
    G_PAM = G.copy()
    i = node_count-1
    G_node_list = np.array((G.nodes()))
    #node probability
    node_prob =[]
    for n in G.nodes():
        prob = G.degree(n)/(2*len(G.edges()))
        node_prob.append(prob)
#node_prob
    
    for n in range(len(new_nodes)):
        i = np.random.choice(new_nodes)
        G_PAM.add_node(i)
        while (G_PAM.degree(i)!=round(avg_deg)):
            j=np.random.choice(G_node_list, p= node_prob)
            print(i,j,G_PAM.degree(i))
            G_PAM.add_edge(i,j)
        new_nodes.remove(i) 
        
    return G_PAM

# %%
GT_pp = GT.copy()
# Billy Sammy 0
# Billy James Rhodes 1
# Billy Captain America: The Winter Soldier* 2
# Taweret Iwua 0
# Taweret Spider-Man: Far from Home* 1
# Taweret Jessica Jones* 2
# Vaughn Harley Keener 0
# Vaughn Shang-Chi and the Legend of the Ten Rings* 1
# Vaughn Lei Kung 2
# Graciela Aguirre Nick Fury 0
# Graciela Aguirre Daredevil* 1
# Graciela Aguirre Jessica Jones* 2
# Darius Luke Cage* 0
# Darius Guardians of the Galaxy* 1
# Darius Dwayne Blaskowski 2
# Millennial Megan Guardians of the Galaxy* 0
# Millennial Megan Klev 1
# Millennial Megan Iron Man 2* 2
# Karolina Dean Trish Walker 0
# Karolina Dean She-Hulk: Attorney at Law* 1
# Karolina Dean She-Hulk: Attorney at Law* 2
# Karolina Dean The Collector 2
# Nathan Bowen The Defenders* 0
# Nathan Bowen Marvel One-Shot: All Hail the King* 1
# Nathan Bowen Avengers: Endgame* 2
# Auntie Chantelle Peter Quill 0
# Auntie Chantelle The Falcon and the Winter Soldier* 1
# Auntie Chantelle Timothy 'Dum Dum' Dugan 2
# Wendy Spector Beverly 0
# Wendy Spector Dottie Underwood 1
# Wendy Spector Ayo 2
# Anton Mogart Avengers: Age of Ultron* 0
# Anton Mogart JARVIS 1
# Anton Mogart Jimmy Woo 2
# Detective Brigid O'Reilly Ayo 0
# Detective Brigid O'Reilly Carlos 1
# Detective Brigid O'Reilly Malcolm Ducasse 2

# %%
# PAM - MU avg deg n clustering 
avg_deg_PAM, avg_clstrng_PAM = avg_deg_cc(PAM_MU)

# %%
# PAM - MU Graph avg path
PAM_avg_path= nx.average_shortest_path_length(PAM_MU)

# %%
print(len(PAM_MU.nodes()), len(PAM_MU.edges()))
# Out:
# 848 1382

# %%
print("PAM-MU Graph \n ")
print("Average degree" ,avg_deg_PAM )
print("Average path", PAM_avg_path)
print("Average clusteirng", avg_clstrng_PAM)
print("MU - PAM graph diameter is", max([max(j.values()) for (i,j) in nx.shortest_path_length(PAM_MU)]))#.subgraph(component)))
# Out:
# PAM-MU Graph
#
# Average degree 3.259433962264151
# Average path 4.5184808758994
# Average clusteirng 0.0017246716490514305
# MU - PAM graph diameter is 8

# %%
val3= PAM_avg_path/GT_avg_path
print(' Average path of Random Model Graph is ',val3,'times the average path of Marvel Uuniverse')
#val4 =   avg_clstrng_PAM /avg_clstrng_
#print('Clustering co-efficient of Random graph is',val4,'times the Clustering co-efficient of Marvel Uuniverse')
# Out:
#  Average path of Random Model Graph is  0.7770380301666721 times the average path of Marvel Uuniverse

# %% [markdown]
# As we removed 6 titles nodes which are in MU network, MU_PAM has 848 nodes. These leads to reduce in average path.

# %%
deg_dst_Graph(PAM_MU)
# similar to the actual Graph

# %% [markdown]
# #### Centralities

# %%
Degree_Centrality = nx.degree_centrality(GT)
#Nodes with high and low degree cenrailities
min_DC = {i for i in Degree_Centrality if Degree_Centrality[i]==min(Degree_Centrality.values())}
max_DC = {i for i in Degree_Centrality if Degree_Centrality[i]==max(Degree_Centrality.values())}
print("Nodes with high degree (", max(Degree_Centrality.values()),")centrality",max_DC,'\n\n Nodes with low degree(',min(Degree_Centrality.values()),') centrality', min_DC)
# Out:
# Nodes with high degree ( 0.07971864009378662 )centrality {'What If...?*'}
#
#  Nodes with low degree( 0.0011723329425556857 ) centrality {'Azarel', 'Jolene Spivey', "Benjamin 'Dex' Poindexter", 'Kaecilius', 'Diego', 'Ruben', 'Holden Holliway', 'Detective Andrew Henry', 'Emil Blonsky', 'Comanche', 'Hai-Qing Yang', 'Taserface-AR', 'Ted (The Man-Thing)', 'Porcupine', 'Betty Ross', 'Sheikh Abdullah', 'White Power Dave', "N'Jobu", 'Paul Edmonds', 'Daniel Drumm', 'Colonel Victor Ramon', 'Louise Thompson', 'Morgan Stark', 'Akihiko', 'Darryl', 'Maya Hansen', 'Secretary Ross-AR', 'Carol', 'Herman', 'Layla El-Faouly', 'Nebula-AR', 'Anansi', 'Night Waitress', 'Vernon Masters', 'Aida', 'Captain Tom Ridenhour', 'Officer Fuchs', 'Skaar', 'Phastos', 'David Schultz', 'Enrique', 'Auntie Ruby', 'Xavin', 'Geoffrey Wilder', 'Tiny', 'Carl Lucas', 'Mrs. Davis', 'Ying Nan', 'Sal Blaskowski', 'Yelena Boleva', 'Topaz', 'Leslie Dean', 'Dr. Bill Foster', 'Griffin Sinclair', 'Harley Keener', 'Maria Hill-AR', 'Ben', 'Derek', 'AJ', 'Jason Ionello', 'Okoye-AR', 'FSB Commander', "Marvel One-Shot: A Funny Thing Happened on the Way to Thor's Hammer*", 'Kamran', 'Otis Johnson', 'Detective Rafael Scarfe', 'Cornell Stokes', 'Aldrich Killian', 'Anton Ivanov', 'Chase Stein', 'Queen Ramonada-AR', 'Gorgon', 'Hank', 'Agent Ford', 'Lance Hunter', 'Ayesha', 'Murakami', 'Sammy', 'Father Joshua Crow', 'Albert Rackham', 'Holden Radcliffe', 'Stacey Yorkes', 'The Ancient One-AR', 'Ajak', 'The Collector-AR', 'Skeevy Guy', 'Colonel Chester Phillips', 'Tony stark-AR', 'Jon Jon', 'Dreykov', 'Dr. Otto Octavius', 'Sharon Carter-AR', 'Judge Price', 'Ravonna Renslayer', 'Ivan Hess', 'Phil Jones', 'Proxima Midnight', 'Klev', 'Lei Kung', 'Gregory Sallinger', 'Graciela Aguirre', 'Nico', 'Battlestar', 'Wendy', 'Grant Ward', 'Mr. Berkowitz', 'Chris Yen', 'Mobius', 'Sinara', 'Alex Wilder', 'Yondu', 'Detective Rivera', 'He Who Remains', 'Shaun', 'Runa', 'Curtis Hoyle', 'Dr. Noah Burstein', 'Herman Schultz', 'Gigi', 'Betty Ross-AR', 'Aamir', 'Dr. Erskine-AR', 'Adrian Toomes', 'Lia', 'Olivia Walker', 'Carlo Eastman', 'Alexandra Reid', 'Ikaris', 'Jack Murdock', "Maximillian 'Max' Tatum", 'Victoria', 'Skurge', 'Billy Russo', 'Dale', 'Calvin Zabo', 'Ulysses Klaue-AR', 'Agent Davis', "W'Kabi", 'Iwua', 'Peter Quill-AR', 'Yinsen', 'Carson Wolf', 'Aaron Davis', 'Dwayne Blaskowski', 'Gao Lei', 'Donna', 'Makkari', 'Red Dagger', 'Special Agent Sonya Falsworth', 'Bronaja', 'Dr. Christine Palmer-AR', 'Rufus', 'Casey', 'Peter Lyonne', 'Sowande', 'Ruihua', 'Gordon', 'Amy Minoru', 'Dr. Christina Raynor', 'Mouse', 'Taweret', 'Dottie Underwood', 'Kilgrave', 'Krista Dumont', 'E.D.I.T.H.', 'Druig', 'Peter Parker3', 'Nathan Bowen', 'Dorothy', 'Lee', 'Shuri-AR', 'Hugh Jones', 'Donald', 'Thanos-AR', 'Maximus', "O'Bengh-AR", 'Kitang', 'Jack Duquesne', 'DeeDee', 'Bruno', 'Bobby Fish', 'Bruce Banner-AR', 'Beverly', 'Gilgamesh', 'Frank', 'Ultron-AR', 'Sergei', 'Alonso Barber', 'Dana Stryker', 'Colonel Flynn-AR', 'Marilyn', 'Reed Richards', 'Hank Pym-AR', 'Liz', 'Jim Morita', 'Sonny Burch', 'Wendy Ross-Hogarth', 'James Rhodes-AR', 'Maggie', 'Dr. Evan Declan', 'Louise', 'Brock Rumlow-AR', 'Robyn', 'Det. Oscar Clemons', 'Obadiah Stane', 'Alpha Dog', 'Finn', 'Officer Derrick Jackson', 'Lieutenant Perez', 'Victoria Helstrom', 'Adina Johnson', 'Thena', 'Razor Fist', 'Vido Arocho', 'Kingo', 'Erik Killmonger', 'Young Xialing', 'Sif-AR', 'Strucker', 'Elaine Walters', 'Ellis', 'John', 'Minn-Erva', 'Abomination', 'Pam', 'Tilda Johnson', 'Liorn', 'Shane', 'Jason Wilkes', 'Dennis Bukowski', 'Miek', 'Tibor', 'Kthara', 'Eugene Patilio', 'Erik Killmonger-AR', 'Ghost Rider', 'Mrs. Chen', 'Fletcher Heggs', 'Aunt Melanie', 'Mordis', 'Jane Foster-AR', 'Gamora-AR', 'Soo', 'Hercules', 'Noah', 'Ebony Maw-AR', 'Luanne', 'Raza', 'Blake Tower', 'Death Dealer', "T'Challa-AR", 'Janice', 'Zuri', 'Linda Chao', 'Agent Vega', 'Happy Sam Sawyer', 'Titania', 'Will Simpson', 'BB', 'Dinah Madani', 'Agent Deever', 'Tamar', 'Howard Stark-AR', 'Dr. Nic West', 'Flint Marko', 'Korath-AR', 'Abu Bakaar', 'D.W. Griffith', 'King Laufey', ...

# %%
EigenVector_Centrality = nx.eigenvector_centrality(GT, max_iter=500)
min_EV = {i for i in EigenVector_Centrality if EigenVector_Centrality[i]==min(EigenVector_Centrality.values())}
max_EV = {i for i in EigenVector_Centrality if EigenVector_Centrality[i]==max(EigenVector_Centrality.values())}
print("Nodes with high Eigen Vector(",max(EigenVector_Centrality.values()),") centrality",max_EV,'\n\n Nodes with low Eigen Vector(',min(EigenVector_Centrality.values()),') centrality', min_EV)
# Out:
# Nodes with high Eigen Vector( 0.4792332447891307 ) centrality {'Avengers: Endgame*'}
#
#  Nodes with low Eigen Vector( 1.8381415818599166e-23 ) centrality {'Azarel', 'Barasso', 'Verussa', 'Elsa Bloodstone', 'Jovan', 'Liorn', 'Ulysses Bloodstone', 'Billy Swan', 'The Flaming Tuba', 'Jack Russell', 'Ted (The Man-Thing)'}

# %%
#Katz_Centality = nx.katz_centrality(GT, max_iter=50000)
#min_KC = {i for i in Katz_Centality if Katz_Centality[i]==min(Katz_Centality.values())}
#max_KC = {i for i in Katz_Centality if Katz_Centality[i]==max(Katz_Centality.values())}
#print("Nodes with high Katz Centality", max_KC,'\n\n Nodes with low Katz_Centality', min_KC)

#Katz unable to find 50k iterations

# %%
PageRank= nx.pagerank(GT)
min_PR = {i for i in PageRank if PageRank[i]==min(PageRank.values())}
max_PR = {i for i in PageRank if PageRank[i]==max(PageRank.values())}
print("Nodes with high PageRank(",max(PageRank.values()),")", max_PR,'\n\n Nodes with low PageRank (',min(PageRank.values()),')', min_PR)
# Out:
# Nodes with high PageRank( 0.03676429431655648 ) {'What If...?*'}
#
#  Nodes with low PageRank ( 0.0003976856366909435 ) {'Proxima Midnight', 'Cull Obsidian', 'Tiny', 'Eitri'}

# %%
Betweenness_Centrality=nx.betweenness_centrality(GT)
min_BC = {i for i in Betweenness_Centrality if Betweenness_Centrality[i]==min(Betweenness_Centrality.values())}
max_BC = {i for i in Betweenness_Centrality if Betweenness_Centrality[i]==max(Betweenness_Centrality.values())}
print("Nodes with high Betweenness(",max(Betweenness_Centrality.values()),") Centrality", max_BC,'\n\n Nodes with low Betweenness (', min(Betweenness_Centrality.values()),') Centrality', min_BC)
# Out:
# Nodes with high Betweenness( 0.28564579659728623 ) Centrality {'Spider-Man: No Way Home*'}
#
#  Nodes with low Betweenness ( 0.0 ) Centrality {'Azarel', 'Jolene Spivey', "Benjamin 'Dex' Poindexter", 'Kaecilius', 'Diego', 'Ruben', 'Holden Holliway', 'Detective Andrew Henry', 'Emil Blonsky', 'Comanche', 'Hai-Qing Yang', 'Taserface-AR', 'Ted (The Man-Thing)', 'Porcupine', 'Betty Ross', 'Sheikh Abdullah', 'White Power Dave', "N'Jobu", 'Paul Edmonds', 'Daniel Drumm', 'Colonel Victor Ramon', 'Louise Thompson', 'Morgan Stark', 'Akihiko', 'Darryl', 'Maya Hansen', 'Secretary Ross-AR', 'Carol', 'Herman', 'Layla El-Faouly', 'Nebula-AR', 'Anansi', 'Night Waitress', 'Vernon Masters', 'Aida', 'Captain Tom Ridenhour', 'Officer Fuchs', 'Skaar', 'Phastos', 'David Schultz', 'Enrique', 'Auntie Ruby', 'Xavin', 'Geoffrey Wilder', 'Tiny', 'Carl Lucas', 'Mrs. Davis', 'Ying Nan', 'Sal Blaskowski', 'Yelena Boleva', 'Topaz', 'Leslie Dean', 'Dr. Bill Foster', 'Griffin Sinclair', 'Harley Keener', 'Maria Hill-AR', 'Ben', 'Derek', 'AJ', 'Jason Ionello', 'Okoye-AR', 'FSB Commander', "Marvel One-Shot: A Funny Thing Happened on the Way to Thor's Hammer*", 'Kamran', 'Otis Johnson', 'Detective Rafael Scarfe', 'Cornell Stokes', 'Aldrich Killian', 'Anton Ivanov', 'Chase Stein', 'Queen Ramonada-AR', 'Gorgon', 'Hank', 'Agent Ford', 'Lance Hunter', 'Ayesha', 'Murakami', 'Sammy', 'Father Joshua Crow', 'Albert Rackham', 'Holden Radcliffe', 'Stacey Yorkes', 'The Ancient One-AR', 'Ajak', 'The Collector-AR', 'Skeevy Guy', 'Colonel Chester Phillips', 'Tony stark-AR', 'Jon Jon', 'Dreykov', 'Dr. Otto Octavius', 'Sharon Carter-AR', 'Judge Price', 'Ravonna Renslayer', 'Ivan Hess', 'Phil Jones', 'Proxima Midnight', 'Klev', 'Lei Kung', 'Gregory Sallinger', 'Graciela Aguirre', 'Nico', 'Battlestar', 'Wendy', 'Grant Ward', 'Mr. Berkowitz', 'Chris Yen', 'Mobius', 'Sinara', 'Alex Wilder', 'Yondu', 'Detective Rivera', 'He Who Remains', 'Shaun', 'Runa', 'Curtis Hoyle', 'Dr. Noah Burstein', 'Herman Schultz', 'Gigi', 'Betty Ross-AR', 'Aamir', 'Dr. Erskine-AR', 'Adrian Toomes', 'Lia', 'Olivia Walker', 'Carlo Eastman', 'Alexandra Reid', 'Ikaris', 'Jack Murdock', "Maximillian 'Max' Tatum", 'Victoria', 'Skurge', 'Billy Russo', 'Dale', 'Calvin Zabo', 'Ulysses Klaue-AR', 'Agent Davis', "W'Kabi", 'Iwua', 'Peter Quill-AR', 'Yinsen', 'Carson Wolf', 'Aaron Davis', 'Dwayne Blaskowski', 'Gao Lei', 'Donna', 'Makkari', 'Red Dagger', 'Special Agent Sonya Falsworth', 'Bronaja', 'Dr. Christine Palmer-AR', 'Rufus', 'Casey', 'Peter Lyonne', 'Sowande', 'Ruihua', 'Gordon', 'Amy Minoru', 'Dr. Christina Raynor', 'Mouse', 'Taweret', 'Dottie Underwood', 'Kilgrave', 'Krista Dumont', 'E.D.I.T.H.', 'Druig', 'Peter Parker3', 'Nathan Bowen', 'Dorothy', 'Lee', 'Shuri-AR', 'Hugh Jones', 'Donald', 'Thanos-AR', 'Maximus', "O'Bengh-AR", 'Kitang', 'Jack Duquesne', 'DeeDee', 'Bruno', 'Bobby Fish', 'Bruce Banner-AR', 'Beverly', 'Gilgamesh', 'Frank', 'Ultron-AR', 'Sergei', 'Alonso Barber', 'Dana Stryker', 'Colonel Flynn-AR', 'Marilyn', 'Reed Richards', 'Hank Pym-AR', 'Liz', 'Jim Morita', 'Sonny Burch', 'Wendy Ross-Hogarth', 'James Rhodes-AR', 'Maggie', 'Dr. Evan Declan', 'Louise', 'Brock Rumlow-AR', 'Robyn', 'Det. Oscar Clemons', 'Obadiah Stane', 'Alpha Dog', 'Finn', 'Officer Derrick Jackson', 'Lieutenant Perez', 'Victoria Helstrom', 'Adina Johnson', 'Thena', 'Razor Fist', 'Vido Arocho', 'Kingo', 'Erik Killmonger', 'Young Xialing', 'Sif-AR', 'Strucker', 'Elaine Walters', 'Ellis', 'John', 'Minn-Erva', 'Abomination', 'Pam', 'Tilda Johnson', 'Liorn', 'Shane', 'Jason Wilkes', 'Dennis Bukowski', 'Miek', 'Tibor', 'Kthara', 'Eugene Patilio', 'Erik Killmonger-AR', 'Ghost Rider', 'Mrs. Chen', 'Fletcher Heggs', 'Aunt Melanie', 'Mordis', 'Jane Foster-AR', 'Gamora-AR', 'Soo', 'Hercules', 'Noah', 'Ebony Maw-AR', 'Luanne', 'Raza', 'Blake Tower', 'Death Dealer', "T'Challa-AR", 'Janice', 'Zuri', 'Linda Chao', 'Agent Vega', 'Happy Sam Sawyer', 'Titania', 'Will Simpson', 'BB', 'Dinah Madani', 'Agent Deever', 'Tamar', 'Howard Stark-AR', 'Dr. Nic West', 'Flint Marko', 'Korath-AR', 'Abu Bakaar', 'D.W. Griffith', 'King Laufey', 'Agent Pipe ...

# %%
Closeness_Centrality = nx.closeness_centrality(GT)
min_CC = {i for i in Closeness_Centrality if Closeness_Centrality[i]==min(Closeness_Centrality.values())}
max_CC = {i for i in Closeness_Centrality if Closeness_Centrality[i]==max(Closeness_Centrality.values())}
print("Nodes with high Closeness(",max(Closeness_Centrality.values()),") Centrality", max_CC,'\n\n Nodes with low Closeness(',min(Closeness_Centrality.values()),') Centrality', min_CC)
# Out:
# Nodes with high Closeness( 0.21872869310813475 ) Centrality {'Avengers: Endgame*'}
#
#  Nodes with low Closeness( 0.006754870764249428 ) Centrality {'Azarel', 'Barasso', 'Verussa', 'Elsa Bloodstone', 'Jovan', 'Liorn', 'Ulysses Bloodstone', 'Billy Swan', 'The Flaming Tuba', 'Jack Russell', 'Ted (The Man-Thing)'}

# %%
#Didn't get Katz Centrality value so ignoring it in Correlation Matrix
Cntrlts={0:list(Degree_Centrality.values()),1:list(EigenVector_Centrality.values()),
         2:list(PageRank.values()),3:list(Betweenness_Centrality.values()),
         4:list(Closeness_Centrality.values())}   
col_names = row_names = ['Degree Centrality', 'EigenVector Centrality',
                         'PageRank','Betweenness Centrality','Closeness Centrality']
matrix = np.empty((5, 5))
df = pd.DataFrame(matrix, columns=col_names, index=row_names)

for i in range(len(Cntrlts)):
    for j in range(len(Cntrlts)):
        x= stats.pearsonr(Cntrlts[i],Cntrlts[j])
        if i<=j: df.loc[row_names[i]][row_names[j]]=df.loc[row_names[j]][row_names[i]]=x.statistic
print(df)
# Out:
#                         Degree Centrality  EigenVector Centrality  PageRank  \
# Degree Centrality                1.000000                0.490222  0.961197
# EigenVector Centrality           0.490222                1.000000  0.281496
# PageRank                         0.961197                0.281496  1.000000
# Betweenness Centrality           0.642821                0.438433  0.558380
# Closeness Centrality             0.198173                0.433183  0.099383
#
#                         Betweenness Centrality  Closeness Centrality
# Degree Centrality                     0.642821              0.198173
# EigenVector Centrality                0.438433              0.433183
# PageRank                              0.558380              0.099383
# Betweenness Centrality                1.000000              0.253709
# Closeness Centrality                  0.253709              1.000000

# %%
p = sns.ecdfplot(data=Cntrlts, legend=True)
p.set(title ="Cumulative Distribution Function (CDF) of 5 centrality measures in one plot")
p.legend(['Degree Centrality ',' EigenVector Centrality ',' PageRank','Betweenness Centrality','Closeness Centrality'], loc =4)
