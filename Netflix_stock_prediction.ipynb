# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/NFLX.csv")
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
data=data.drop('Adj Close',axis=1)

# %%
data
# Out:
#             Date        Open        High         Low       Close    Volume
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  11896100
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  12595800
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998   8981500
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006   9306700
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  16906900
# ...          ...         ...         ...         ...         ...       ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  20047500
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  22542300
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  14346000
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006   9905200
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013   7782400
#
# [1009 rows x 6 columns]

# %%
data['year'] = pd.to_datetime(data['Date']).dt.year
data['month'] = pd.to_datetime(data['Date']).dt.month
data['day'] = pd.to_datetime(data['Date']).dt.day

data
# Out:
#             Date        Open        High         Low       Close    Volume  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  11896100
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  12595800
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998   8981500
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006   9306700
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  16906900
# ...          ...         ...         ...         ...         ...       ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  20047500
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  22542300
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  14346000
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006   9905200
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013   7782400
#
#       year  month  day
# 0     2018      2    5
# ...

# %% [markdown]
# #Visualisation

# %%
import seaborn as sns
sns.barplot(y = 'Close', x = 'year', color='blue',saturation = 1,edgecolor="1",data = data)

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

plt.title('Line Plot of VOLUME graph')
year = data['year']
Volume=data['Volume']
sns.lineplot(x=year, y=Volume,ci=None)

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = data.drop(['year','month','day'],axis=1)
start_date = df["Date"].iloc[0]
end_date = df["Date"].iloc[-1]                     
df['Date'] = pd.to_datetime(df['Date']) 
new_df = (df['Date']>= start_date) & (df['Date']<= end_date)
df1 = df.loc[new_df]
stock_data = df1.set_index('Date')
stock_data.plot(subplots = True, figsize = (8, 8));
plt.legend(loc = 'best')
plt.suptitle('Open,High,Low,Close prices & Volume of Netflix', fontsize=12, color='black')
plt.show()

# %%
#plot close price of netflix
data['Close'].plot()
plt.title("Close price graph")
plt. xlabel("Count")
plt.ylabel("values")

plt.show()

# %% [markdown]
# #Data Splitting & Normalisation

# %%
Y=data['Close']
X=data[['High','Low','Open']]

# %%
X.isnull().sum()
# Out:
# High    0
# Low     0
# Open    0
# dtype: int64

# %%
X
# Out:
#             High         Low        Open
# 0     267.899994  250.029999  262.000000
# 1     266.700012  245.000000  247.699997
# 2     272.450012  264.329987  266.579987
# 3     267.619995  250.000000  267.079987
# 4     255.800003  236.110001  253.850006
# ...          ...         ...         ...
# 1004  427.700012  398.200012  401.970001
# 1005  458.480011  425.540009  432.959991
# 1006  451.980011  426.480011  448.250000
# 1007  429.260010  404.279999  421.440002
# 1008  412.769989  396.640015  407.309998
#
# [1009 rows x 3 columns]

# %%
Y
# Out:
# 0       254.259995
# 1       265.720001
# 2       264.559998
# 3       250.100006
# 4       249.470001
#            ...
# 1004    427.140015
# 1005    457.130005
# 1006    429.480011
# 1007    405.600006
# 1008    410.170013
# Name: Close, Length: 1009, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
Scale = MinMaxScaler()
xScaled = Scale.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.30)

# %%
print(X_train.shape,Y_train.shape,X_test.shape,Y_test.shape)
# Out:
# (706, 3) (706,) (303, 3) (303,)

# %%
X_train
# Out:
#            High         Low        Open
# 447  293.410004  281.140015  291.029999
# 664  477.000000  467.820007  470.529999
# 198  292.500000  282.160004  285.510010
# 515  372.820007  361.000000  364.760010
# 919  609.880005  588.010010  589.010010
# ..          ...         ...         ...
# 468  301.799988  297.250000  298.500000
# 778  518.969971  504.250000  513.500000
# 600  472.359985  454.000000  468.540009
# 15   297.359985  290.589996  294.769989
# 510  385.149994  379.429993  381.470001
#
# [706 rows x 3 columns]

# %%
Y_train
# Out:
# 447    283.109985
# 664    473.079987
# 198    290.059998
# 515    368.700012
# 919    599.059998
#           ...
# 468    298.500000
# 778    504.540009
# 600    457.850006
# 15     290.609985
# 510    380.399994
# Name: Close, Length: 706, dtype: float64

# %%
X_test
# Out:
#            High         Low        Open
# 692  495.309998  478.760010  484.929993
# 294  365.940002  359.929993  365.109985
# 826  493.480011  486.190002  488.399994
# 332  347.660004  332.649994  343.559998
# 358  384.339996  362.679993  382.769989
# ..          ...         ...         ...
# 473  338.000000  330.600006  335.000000
# 7    269.880005  260.329987  260.470001
# 141  374.489990  360.000000  367.149994
# 623  497.790009  487.760010  496.019989
# 864  545.330017  535.760010  535.760010
#
# [303 rows x 3 columns]

# %%
Y_test
# Out:
# 692    487.220001
# 294    361.410004
# 826    486.279999
# 332    336.630005
# 358    381.000000
#           ...
# 473    336.899994
# 7      266.000000
# 141    364.579987
# 623    488.510010
# 864    540.679993
# Name: Close, Length: 303, dtype: float64

# %% [markdown]
# #Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
  
 # create regressor object
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
  
# fit the regressor with x and y data
regressor.fit(X_train,Y_train) 
prediction = regressor.predict(X_test)

# %%
prediction
# Out:
# array([487.31459771, 363.21829526, 491.24809751, 337.80460218,
#        373.63090174, 476.43080155, 301.87709869, 350.72949578,
#        354.49289682, 314.4813975 , 487.97989918, 595.02419326,
#        292.82609705, 434.18659684, 340.00760252, 502.23928834,
#        359.89040147, 396.04320336, 314.74969043, 380.8285959 ,
#        570.31399239, 488.5913995 , 397.45980259, 353.9157988 ,
#        366.59520136, 492.52669821, 348.75439381, 610.83210971,
#        633.15678537, 319.14700468, 359.88540209, 352.07009522,
#        562.74881296, 314.02630068, 355.227605  , 326.38809895,
#        294.34579669, 431.75170638, 488.78239934, 364.84829825,
#        354.09479921, 585.3467007 , 336.86730202, 303.86900307,
#        269.66719513, 296.71430084, 518.88550122, 528.96380845,
#        381.83629621, 377.9361932 , 284.98279595, 499.03089368,
#        549.74089419, 344.76549641, 321.73959965, 419.35190048,
#        521.11759348, 434.98319887, 346.88159912, 317.52039524,
# ...

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score,accuracy_score
from math import sqrt

mse = mean_squared_error(Y_test, prediction)
errors = abs(prediction - Y_test)
mape = 100 * (errors / Y_test)
accuracy = 100 - np.mean(mape)
regressor.score(X_test,Y_test)
print("Accuracy Score: ",round(accuracy,2))
print("Mean Squared Error: ",round(mse,2))
# Out:
# Accuracy Score:  99.14
# Mean Squared Error:  22.92

# %%
df = pd.DataFrame({'Actual': Y_test, 'Predicted': prediction})
df1=df.reset_index(drop=True, inplace=True)
df1 = df.head(100)
df1
# Out:
#         Actual   Predicted
# 0   487.220001  487.314598
# 1   361.410004  363.218295
# 2   486.279999  491.248098
# 3   336.630005  337.804602
# 4   381.000000  373.630902
# ..         ...         ...
# 95  392.869995  387.362903
# 96  424.989990  424.655003
# 97  533.500000  534.048797
# 98  292.010010  292.918998
# 99  387.149994  369.170799
#
# [100 rows x 2 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
plt.plot(df1['Actual'], label='Actual', color='red')
plt.plot(df1['Predicted'], label='Predicted', color='blue')
plt.legend()
plt.title('Line Plot of Actual and Predicted values of Random Forest')
plt. xlabel("Count")
plt.ylabel("Values")
plt.figure(figsize=(200, 200))
plt.show()

# %% [markdown]
# #Arima MOdel

# %%
from statsmodels.tsa.arima.model import ARIMA as ARIMA

# %%
# split into train and test sets
size = int(len(Y) * 0.77)
train, test = Y[0:size], Y[size:len(Y)]
history = [x for x in train]
predictions = list()
actual = list()
# walk-forward validation
for t,u in zip(range(len(test)),test):
  model = ARIMA(history, order=(5,1,0))
  model_fit = model.fit()
  output = model_fit.forecast()
  yhat = output[0]
  predictions.append(yhat)
  actual.append(u)
  obs = u
  history.append(obs)
  print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=514.976684, expected=493.329987
# predicted=493.828858, expected=506.440002
# predicted=506.342790, expected=504.540009
# predicted=506.457955, expected=523.059998
# predicted=518.338816, expected=518.020020
# predicted=522.087621, expected=520.250000
# predicted=518.275548, expected=524.030029
# predicted=525.450472, expected=524.440002
# predicted=522.305377, expected=504.790009
# predicted=507.590978, expected=512.179993
# predicted=511.223554, expected=523.109985
# predicted=521.936440, expected=535.090027
# predicted=532.030509, expected=520.809998
# predicted=524.777226, expected=502.859985
# predicted=504.751699, expected=508.049988
# predicted=507.786143, expected=513.950012
# predicted=511.439136, expected=513.390015
# predicted=513.028769, expected=521.659973
# predicted=522.658286, expected=539.419983
# predicted=537.590355, expected=540.669983
# predicted=539.842485, expected=544.530029
# predicted=544.510705, expected=546.989990
# ...

# %%
# Summary of model
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 1008
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               -3843.704
# Date:                Sat, 10 Dec 2022   AIC                           7699.407
# Time:                        05:49:32   BIC                           7728.896
# Sample:                             0   HQIC                          7710.611
#                                - 1008
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0475      0.029     -1.641      0.101      -0.104       0.009
# ar.L2          0.0152      0.025      0.597      0.550      -0.035       0.065
# ar.L3          0.0079      0.031      0.257      0.797      -0.052       0.068
# ...

# %%
from matplotlib import pyplot
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error

from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
#Mean Absolute Error (MAE)
print("\n\nMean Absolute Error (MAE) -: ",mean_absolute_error(actual,predictions))
#Mean Absolute percentage Error (MAPE)
print("Mean Absolute percentage Error (MAPE) -: ",mean_absolute_percentage_error(actual,predictions))
# Mean square error (MSE)
print("Mean square error (MSE) -: ",mean_squared_error(actual,predictions))
# Root mean squared error (RMSE)
rmse = sqrt(mean_squared_error(actual,predictions))
print('Root mean squared error (RMSE): %.3f' % rmse)
# Out:
# Mean Absolute Error (MAE) -:  8.18045343850678
# Mean Absolute percentage Error (MAPE) -:  0.015458335330422983
# Mean square error (MSE) -:  170.6124091735993
# Root mean squared error (RMSE): 13.062

# %%
# plot predicted values against actual outcomes

pyplot.plot(actual)
pyplot.plot(predictions, color='red')
plt.title('Line Plot of Actual and Predicted values of ARIMA')
plt. xlabel("Count")
plt.ylabel("Values")
pyplot.show()

# %%
indexe_list = []
for i in range(size,len(Y),1):
  indexe_list.append(i)

# %%
df = pd.DataFrame(predictions,index= indexe_list, columns =['Prediction'])
df['Actual'] = pd.DataFrame(actual,index= indexe_list)
df.head(30)
# Out:
#      Prediction      Actual
# 776  514.976684  493.329987
# 777  493.828858  506.440002
# 778  506.342790  504.540009
# 779  506.457955  523.059998
# 780  518.338816  518.020020
# 781  522.087621  520.250000
# 782  518.275548  524.030029
# 783  525.450472  524.440002
# 784  522.305377  504.790009
# 785  507.590978  512.179993
# 786  511.223554  523.109985
# 787  521.936440  535.090027
# 788  532.030509  520.809998
# 789  524.777226  502.859985
# 790  504.751699  508.049988
# 791  507.786143  513.950012
# 792  511.439136  513.390015
# 793  513.028769  521.659973
# 794  522.658286  539.419983
# 795  537.590355  540.669983
# 796  539.842485  544.530029
# 797  544.510705  546.989990
# 798  547.504262  554.580017
# 799  552.198410  555.309998
# 800  555.458278  552.780029
# 801  552.762912  553.729980
# 802  554.046954  540.020020
# 803  540.904755  549.219971
# 804  547.837092  546.539978
# 805  547.487866  554.440002

# %%
fig = plt.figure(figsize=(20,8))
num_points = len(Y)
#Forecast = model1.predict(start=(707), end=(1009), dynamic=False)

plt.plot(Y)
plt.plot(df['Prediction'], color='r')

# %% [markdown]
# #LSTM Model

# %%
from sklearn.metrics import mean_absolute_error
from keras.models import Sequential
from sklearn import metrics
import tensorflow as tf
from keras.layers import Dense, LSTM, Dropout,Flatten

model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error',metrics=[tf.keras.metrics.CategoricalAccuracy()])
history=model.fit(X_train,Y_train,epochs=5,batch_size=32)
# Out:
# Epoch 1/5
# 23/23 [==============================] - 8s 12ms/step - loss: 185879.1094 - categorical_accuracy: 1.0000
# Epoch 2/5
# 23/23 [==============================] - 0s 12ms/step - loss: 181044.9219 - categorical_accuracy: 1.0000
# Epoch 3/5
# 23/23 [==============================] - 0s 13ms/step - loss: 177108.5312 - categorical_accuracy: 1.0000
# Epoch 4/5
# 23/23 [==============================] - 0s 13ms/step - loss: 175651.6094 - categorical_accuracy: 1.0000
# Epoch 5/5
# 23/23 [==============================] - 0s 12ms/step - loss: 174458.3906 - categorical_accuracy: 1.0000

# %%
# import matplotlib.pyplot as plt

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs = range(len(loss))

# plt.plot(epochs, loss, 'r', label='Training loss')
# plt.plot(epochs, val_loss, 'b', label='Validation loss')
# plt.title('Training and Validation loss')
# plt.legend(loc=0)
# plt.figure()
# plt.show()

# %%
train_predict2=model.predict(X_train)
test_predict2=model.predict(X_test)
train_predict2.shape, test_predict2.shape
# Out:
# ...
# 10/10 [==============================] - 0s 4ms/step
# ((706, 1), (303, 1))

# %%
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
print("Test data RMSE: ", math.sqrt(mean_squared_error(Y_test,test_predict2)))
print("Test data MSE: ", mean_squared_error(Y_test,test_predict2))
print("Test data MAE: ", mean_absolute_error(Y_test,test_predict2))
# Out:
# Test data RMSE:  420.5985148527786
# Test data MSE:  176903.110696363
# Test data MAE:  407.26451413794024

# %%
print("Train data R2 score:", r2_score(Y_train, train_predict2))
print("Test data R2 score:", r2_score(Y_test, test_predict2))
# Out:
# Train data R2 score: -13.489749955903273
# Test data R2 score: -15.025679620653207

# %%
l_pred=model.predict(X_test)
l_pred=l_pred.flatten()
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
df3 = pd.DataFrame({'Actual': Y_test, 'Predicted': l_pred})
df4=df3.reset_index(drop=True, inplace=True)


df3
# Out:
#          Actual  Predicted
# 0    487.220001  15.205754
# 1    361.410004  15.205751
# 2    486.279999  15.205754
# 3    336.630005  15.205750
# 4    381.000000  15.205753
# ..          ...        ...
# 298  336.899994  15.205749
# 299  266.000000  15.205711
# 300  364.579987  15.205752
# 301  488.510010  15.205754
# 302  540.679993  15.205754
#
# [303 rows x 2 columns]

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
plt.plot(df3['Actual'], label='Actual', color='blue')
plt.plot(df3['Predicted'], label='Predicted', color='red')
plt.legend()
plt.title('Line Plot of Actual and Predicted values')
plt.title("Close price graph")
plt. xlabel("Count")
plt.ylabel("values")
plt.figure(figsize=(200, 200))
plt.show()
